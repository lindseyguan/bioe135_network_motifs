# %%
import networkx as nx
import matplotlib.pyplot as plt

# G1 = nx.read_gml("tf_operon_graph_all.gml")
# plt.subplot(121)
# plt.figure(figsize=(20,20))
# nx.draw_kamada_kawai(G1, with_labels=True)
# plt.savefig("vis_tf_operon.png")

# %%
G2 = nx.read_gml("mcstats_tfType7.gml")
plt.subplot(121)
plt.figure(figsize=(20,20))
nx.draw(G2)
plt.savefig("type7_tf_tf.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/networkx/readwrite/gml.py in pop_attr(dct, category, attr, i)
#     427         try:
# --> 428             return dct.pop(attr)
#     429         except KeyError:
#
# KeyError: 'label'
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-5-57df8ca1ba66> in <module>
# ----> 1 G2 = nx.read_gml("mcstats_tfType7.gml")
#       2 plt.subplot(121)
#       3 plt.figure(figsize=(20,20))
#       4 nx.draw(G2)
#       5 plt.savefig("type7_tf_tf.png")
#
# <//anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-777> in read_gml(path, label, destringizer)
#
# //anaconda3/lib/python3.7/site-packages/networkx/utils/decorators.py in _open_file(func_to_be_decorated, *args, **kwargs)
# ...
